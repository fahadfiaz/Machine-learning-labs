# %% [markdown]
# #### System specifications on which experiments were run!!! Ram-> 4GB, Core i5

# %% [markdown]
# #### I was unable to process all the 128 datasets because it was taking alot of time to process some datasets, So I just run this task on 12 datasets in repository!!!. As the code works for first 12 datasets, it will also work for other datasets.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import neighbors
import math
import warnings
import os
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from operator import itemgetter
import functools
plt.style.use('seaborn-whitegrid')
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load all datasets in repository and get different statistics about each dataset. Also get list of datasets having missing value or unequal length.

# %%
path = "./UCRArchive_2018"
dir_list = os.listdir(path) 
DatasetNames = []

dir_list.remove("Missing_value_and_variable_length_datasets_adjusted")
for datasets_name in dir_list:
    
    DatasetNames.append(datasets_name)

# %% [markdown]
# ## Datasets that we are going to use for this exercise!!!

# %%
sampled_datasets = DatasetNames[:12]
sampled_datasets[2] = "DiatomSizeReduction"
sampled_datasets[3] = "Coffee"
sampled_datasets[4] = "Computers"
sampled_datasets
# Out:
# ['ACSF1',
#  'Adiac',
#  'DiatomSizeReduction',
#  'Coffee',
#  'Computers',
#  'ArrowHead',
#  'Beef',
#  'BeetleFly',
#  'BirdChicken',
#  'BME',
#  'Car',
#  'CBF']

# %% [markdown]
# ### Function to split the dataset into train, test and validation sets

# %%
def split(df,targetcol):
    
    X = df
    Y = targetcol 
    X_copy = X.copy()
    
    Xtrain = X_copy.sample(frac=0.70, random_state=0)
    Xtest = X_copy.drop(Xtrain.index)
    Xtest_copy = Xtest.copy()
    Xtest = Xtest_copy.sample(frac=0.50, random_state=1)
    Xvalidate = Xtest_copy.drop(Xtest.index)
    norm_Xtrain = np.linalg.norm(Xtrain, axis = 1, keepdims = True)
    Xtrain = Xtrain / norm_Xtrain
    norm_Xtest = np.linalg.norm(Xtest, axis = 1, keepdims = True)
    Xtest = Xtest / norm_Xtest
    norm_Xval = np.linalg.norm(Xvalidate, axis = 1, keepdims = True)
    Xval = Xvalidate / norm_Xval
    Y_copy = Y.copy()
    Ytrain = Y_copy.sample(frac=0.70, random_state=0)
    Ytest = Y_copy.drop(Ytrain.index)
    Ytest_copy = Ytest.copy()
    Ytest = Ytest_copy.sample(frac=0.50, random_state=1)
    Yvalidate = Ytest_copy.drop(Ytest.index)
    Ytrain = np.matrix(Ytrain)
    Ytest = np.matrix(Ytest)
    Yval = np.matrix(Yvalidate)
    
    return Xtrain, Ytrain, Xval, Yval, Xtest, Ytest

# %% [markdown]
# ### Function to calculate the euclidean distance

# %%
def eucl_dist2(a , b):
    distance = np.sum(np.square(a-b),axis=1)
    return np.sqrt(distance)

# %%
def eucl_dist(a , b):
    distance = np.sum(np.square(a-b))
    return np.sqrt(distance)

# %% [markdown]
# ### Function that will impute the missing values with the the mean of its nearest K neighbors

# %%
def replace_missing_values_Knn(df_train, k):
    X = df_train.copy()
    X = X.dropna(axis='columns')

    for i, row in X.iterrows():
        
        if df_train.iloc[i,:].isnull().values.any():        
            unique_id = i
            other_rows = X[~X.index.isin([i])]
            res = eucl_dist2(X, row)
            srt = np.argsort(res)[1:k+1]
            replacesment = np.mean(res[srt])
            df_train.iloc[i,:].fillna(replacesment, inplace=True)

    return df_train

# %% [markdown]
# ### Function to calculate the k- nearest distances of query with training dataset with specific distance measure.

# %%
def best_nn(df , query , k, distName):
    distance =[]
    if k > df.shape[0]:
        k = df.shape[0]
    
    ts = pd.DataFrame({0:query}).T
    
### Pdist function only calculate pairwise distances between each observations of input matrix. To make it work in our case
### we have to concatenate query row with row of train dataset, pass this stacked matric to Pdist function and do this operation
### for each row of train dataset.This approach was very slow and was taking alot of time. 

### So to make this approach faster, I stacked the query row on top of train dataset matrix and then found the distance using
### following approach which was quite faster then processing individual row of train matrix with query row.
    

    df_concat = pd.concat([ts, df], axis=0) 
    
### pdist will give us Pairwise distances between each observations.Then we use squareform function to convert this pairwise
### distance vector to a square-form distance matrix. Now each row is a pairwise distance between each observation. 
### The distance between query row and train matrix will be found at 0 index of distance matrix. We ignore the 0 index because it
### is a distance of query row from query row which will be zero. So we ignore the 0 index of final distance list

    distance = squareform(pdist(df_concat,distName))[0][1:]

    agg = np.argsort(distance)[:k]
    return agg

# %% [markdown]
# ### Function to  calculate k-neareast neighbours and do majority voting to get final prediction

# %%
def prediction(x , y , query, k, distName):
    predictions = []
    
    for index,row1 in query.iterrows():        
        k_min = best_nn(x , row1 , k, distName)
        m = y[k_min].tolist()
        predictions.append(max(m , key=m.count))
    return predictions

# %% [markdown]
# ### Function to get accuracy on specific dataset

# %%
def get_accuracy(a , p):

    count = 0
    for i ,j in zip(a , p):
        if (i == j):
            count += 1
    return (count/a.shape[0]) * 100

# %% [markdown]
# ### All distance measure provided by scipy library

# %%
distNames = ["","euclidean", "minkowski", "cityblock", "seuclidean", "sqeuclidean","cosine","correlation","hamming","jaccard",
            "chebyshev","canberra","braycurtis","yule","matching","dice","kulsinski","rogerstanimoto","russellrao",
             "sokalmichener", "sokalsneath"]

# %% [markdown]
# ### Main Function

# %%
try:
    for ds in sampled_datasets:
    
        train_pt = "./UCRArchive_2018\\" + ds + "\\"+ ds + "_TRAIN.tsv"
        test_pt = "./UCRArchive_2018\\" + ds + "\\"+ ds + "_TEST.tsv"
        df_train = pd.read_csv(train_pt, sep='\t', header=None)
        df_test = pd.read_csv(test_pt, sep='\t', header=None)
        df_full = df_train.append(df_test)
        df_full.reset_index(drop=True, inplace=True)
        df_train = df_full.iloc[:,1:]
        df_test = df_full.iloc[:,0]

        print("##############################################--",ds," Dataset -- Started\n")
        print("Full Dataset Shape ",df_full.shape )
        print( "Check if dataset has null values or missing values!!! ",np.isnan(df_train.values).any()) 
        print("\nK-nearest neighbour started!!!")

        listAccr = np.zeros((11,21)) # Outer list index is to get optimal k-for prediction, Inner list will save results of predictions 
                                     # using different distance measure!!!

        for k1 in range(0,10): # grid search to get best k for doing prediction
            for k2 in range(0,20): # use different distance measures for prediction

                Xtrain, Ytrain, Xval, Yval, Xtest, Ytest = split(df_train,df_test) # Split the dataset!!!

                pred = prediction(Xtrain, np.array(Ytrain)[0], Xval, k1+1 , distNames[k2+1]) # Do prediction with each distance 
                                                                                             #  measure.

                listAccr[k1+1,k2+1] = get_accuracy(np.array(Yval)[0], pred)

            print("Predictions done with k: ", k1+1)

        print("K-nearest neighbour finished!!!")
        print("Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'\n")
        print(listAccr[1:,1:])

        indx = np.unravel_index(np.nanargmax(listAccr), listAccr.shape) # get maximum accuracy index

        best_accr = [[i,np.argmax(sublist),max(reversed(sublist))] for i, sublist in enumerate(listAccr)]
        best_metric = sorted(best_accr, key=itemgetter(2), reverse=True)
        k_best , distance_type, accuracy = best_metric[0]

        print("\n Optimal K for prediction: ",k_best, ", Optimal distance measure for prediction: ", distNames[distance_type], ", Accuracy on these optimal paramters: ",accuracy )

        print("\nCalculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!")

        ### Now do prediction on test set with optimal paramters!!!

        Xtrain0, Ytrain0, Xval0, Yval0, Xtest0, Ytest0 = split(df_train,df_test)

        pred = prediction(Xtrain0, np.array(Ytrain0)[0], Xtest0, k_best, distNames[distance_type] )

        print("\nFinal accuracy on test data: ", get_accuracy(np.array(Ytest0)[0], pred))
        print("\nFinished --",ds," Dataset--##############################################\n\n")
except:
    pass
# Out:
# ##############################################-- ACSF1  Dataset -- Started
#
# Full Dataset Shape  (200, 1461)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[53.33333333 53.33333333 73.33333333 66.66666667 53.33333333 53.33333333
#   53.33333333  3.33333333  3.33333333 40.         73.33333333 73.33333333
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [53.33333333 53.33333333 73.33333333 66.66666667 53.33333333 53.33333333
#   53.33333333  3.33333333  3.33333333 40.         73.33333333 73.33333333
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [46.66666667 46.66666667 63.33333333 50.         46.66666667 46.66666667
#   46.66666667  3.33333333  3.33333333 33.33333333 66.66666667 63.33333333
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [46.66666667 46.66666667 66.66666667 56.66666667 46.66666667 46.66666667
#   46.66666667  6.66666667  6.66666667 30.         66.66666667 63.33333333
#    6.66666667  6.66666667  6.66666667  6.66666667  6.66666667  6.66666667
#    6.66666667  6.66666667]
#  [43.33333333 43.33333333 63.33333333 46.66666667 43.33333333 43.33333333
#   43.33333333  3.33333333  3.33333333 30.         63.33333333 60.
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [46.66666667 46.66666667 60.         46.66666667 46.66666667 46.66666667
#   46.66666667  3.33333333  3.33333333 26.66666667 60.         60.
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [40.         40.         53.33333333 46.66666667 40.         40.
#   40.          3.33333333  3.33333333 23.33333333 53.33333333 56.66666667
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [40.         40.         56.66666667 46.66666667 40.         40.
#   40.          3.33333333  3.33333333 23.33333333 56.66666667 53.33333333
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [36.66666667 36.66666667 56.66666667 46.66666667 36.66666667 36.66666667
#   36.66666667  3.33333333  3.33333333 23.33333333 56.66666667 53.33333333
#    3.33333333  3.33333333  3.33333333  3.33333333  3.33333333  3.33333333
#    3.33333333  3.33333333]
#  [36.66666667 36.66666667 56.66666667 53.33333333 36.66666667 36.66666667
#   36.66666667 13.33333333 13.33333333 23.33333333 50.         56.66666667
#   13.33333333 13.33333333 13.33333333 13.33333333 13.33333333 13.33333333
#   13.33333333 13.33333333]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  cityblock , Accuracy on these optimal paramters:  73.33333333333333
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  73.33333333333333
#
# Finished -- ACSF1  Dataset--##############################################
#
#
# ##############################################-- Adiac  Dataset -- Started
#
# Full Dataset Shape  (781, 177)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[66.66666667 66.66666667 63.24786325 69.23076923 66.66666667 66.66666667
#   66.66666667  2.56410256  2.56410256 64.1025641  52.13675214 63.24786325
#    2.56410256  2.56410256  2.56410256  2.56410256  2.56410256  2.56410256
#    2.56410256  2.56410256]
#  [66.66666667 66.66666667 63.24786325 69.23076923 66.66666667 66.66666667
#   66.66666667  2.56410256  2.56410256 64.1025641  52.13675214 63.24786325
#    2.56410256  2.56410256  2.56410256  2.56410256  2.56410256  2.56410256
#    2.56410256  2.56410256]
#  [64.1025641  64.1025641  63.24786325 65.81196581 64.1025641  64.1025641
#   64.1025641   2.56410256  2.56410256 64.1025641  52.99145299 63.24786325
#    2.56410256  2.56410256  2.56410256  2.56410256  2.56410256  2.56410256
#    2.56410256  2.56410256]
#  [62.39316239 62.39316239 61.53846154 64.1025641  62.39316239 62.39316239
#   62.39316239  2.56410256  2.56410256 58.97435897 52.99145299 62.39316239
#    2.56410256  2.56410256  2.56410256  2.56410256  2.56410256  2.56410256
#    2.56410256  2.56410256]
#  [61.53846154 61.53846154 59.82905983 60.68376068 61.53846154 61.53846154
#   61.53846154  2.56410256  2.56410256 60.68376068 51.28205128 59.82905983
#  [100.         100.         100.         100.         100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.         100.          55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]
#  [100.         100.         100.         100.         100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.         100.          55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]
#  [100.         100.         100.         100.         100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.         100.          55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]
#  [100.         100.         100.          88.88888889 100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.         100.          55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]
#  [100.         100.         100.         100.         100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.          88.88888889  55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]
#  [100.         100.         100.         100.         100.
#   100.         100.          55.55555556  55.55555556 100.
#   100.         100.          55.55555556  55.55555556  55.55555556
#    55.55555556  55.55555556  55.55555556  55.55555556  55.55555556]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  euclidean , Accuracy on these optimal paramters:  100.0
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  100.0
#
# Finished -- Coffee  Dataset--##############################################
#
#
# ##############################################-- Computers  Dataset -- Started
#
# Full Dataset Shape  (500, 721)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[48.         48.         41.33333333 46.66666667 48.         48.
#   48.         54.66666667 54.66666667 58.66666667 45.33333333 46.66666667
#   54.66666667 54.66666667 54.66666667 54.66666667 54.66666667 54.66666667
#   54.66666667 54.66666667]
#  [48.         48.         41.33333333 46.66666667 48.         48.
#   48.         54.66666667 54.66666667 58.66666667 45.33333333 46.66666667
#   54.66666667 54.66666667 54.66666667 54.66666667 54.66666667 54.66666667
#   54.66666667 54.66666667]
#  [40.         40.         48.         45.33333333 40.         40.
#   40.         54.66666667 54.66666667 57.33333333 49.33333333 50.66666667
#   54.66666667 54.66666667 54.66666667 54.66666667 54.66666667 54.66666667
#   54.66666667 54.66666667]
#  [46.66666667 46.66666667 46.66666667 45.33333333 46.66666667 46.66666667
#   46.66666667 54.66666667 54.66666667 61.33333333 48.         49.33333333
#   54.66666667 54.66666667 54.66666667 54.66666667 54.66666667 54.66666667
#   54.66666667 54.66666667]
#  [50.66666667 50.66666667 46.66666667 45.33333333 50.66666667 50.66666667
#   50.66666667 54.66666667 54.66666667 64.         50.66666667 46.66666667
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [44.44444444 44.44444444 33.33333333 44.44444444 44.44444444 44.44444444
#   44.44444444 22.22222222 22.22222222 55.55555556 44.44444444 33.33333333
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [44.44444444 44.44444444 33.33333333 33.33333333 44.44444444 44.44444444
#   44.44444444 22.22222222 22.22222222 55.55555556 44.44444444 33.33333333
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [44.44444444 44.44444444 22.22222222 44.44444444 44.44444444 44.44444444
#   44.44444444 22.22222222 22.22222222 33.33333333 33.33333333 33.33333333
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [22.22222222 22.22222222 33.33333333 33.33333333 22.22222222 22.22222222
#   22.22222222 22.22222222 22.22222222 33.33333333 33.33333333 33.33333333
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [22.22222222 22.22222222 33.33333333 33.33333333 22.22222222 22.22222222
#   22.22222222 22.22222222 22.22222222 33.33333333 33.33333333 33.33333333
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [33.33333333 33.33333333 44.44444444 44.44444444 33.33333333 33.33333333
#   33.33333333 22.22222222 22.22222222 33.33333333 44.44444444 44.44444444
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [33.33333333 33.33333333 22.22222222 44.44444444 33.33333333 33.33333333
#   33.33333333 22.22222222 22.22222222 22.22222222 44.44444444 22.22222222
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  seuclidean , Accuracy on these optimal paramters:  66.66666666666666
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  44.44444444444444
#
# Finished -- Beef  Dataset--##############################################
#
#
# ##############################################-- BeetleFly  Dataset -- Started
#
# Full Dataset Shape  (40, 513)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[66.66666667 66.66666667 50.         66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667 66.66666667 66.66666667 50.         50.
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [66.66666667 66.66666667 50.         66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667 66.66666667 66.66666667 50.         50.
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [33.33333333 33.33333333 16.66666667 33.33333333 33.33333333 33.33333333
#   33.33333333 66.66666667 66.66666667 66.66666667 16.66666667 33.33333333
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [50.         50.         33.33333333 50.         50.         50.
#   50.         66.66666667 66.66666667 66.66666667 33.33333333 33.33333333
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [50.         50.         50.         50.         50.         50.
#   50.         33.33333333 33.33333333 83.33333333 50.         50.
#   33.33333333 33.33333333 33.33333333 33.33333333 33.33333333 33.33333333
#   33.33333333 33.33333333]
#  [83.33333333 83.33333333 50.         66.66666667 83.33333333 83.33333333
#   83.33333333 66.66666667 66.66666667 66.66666667 50.         83.33333333
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [50.         50.         50.         50.         50.         50.
#   50.         33.33333333 33.33333333 66.66666667 33.33333333 66.66666667
#   33.33333333 33.33333333 33.33333333 33.33333333 33.33333333 33.33333333
#   33.33333333 33.33333333]
#  [50.         50.         66.66666667 66.66666667 50.         50.
#   50.         66.66666667 66.66666667 66.66666667 33.33333333 66.66666667
#   66.66666667 66.66666667 66.66666667 66.66666667 66.66666667 66.66666667
#   66.66666667 66.66666667]
#  [50.         50.         50.         50.         50.         50.
#   50.         33.33333333 33.33333333 66.66666667 50.         50.
#   33.33333333 33.33333333 33.33333333 33.33333333 33.33333333 33.33333333
#   33.33333333 33.33333333]
#  [50.         50.         50.         50.         50.         50.
#   50.         33.33333333 33.33333333 66.66666667 50.         50.
#   33.33333333 33.33333333 33.33333333 33.33333333 33.33333333 33.33333333
#   33.33333333 33.33333333]]
#
#  Optimal K for prediction:  5 , Optimal distance measure for prediction:  chebyshev , Accuracy on these optimal paramters:  83.33333333333334
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  66.66666666666666
#
# Finished -- BeetleFly  Dataset--##############################################
#
#
# ##############################################-- BirdChicken  Dataset -- Started
#
# Full Dataset Shape  (40, 513)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[ 50.          50.          50.         100.          50.
#    50.          50.          66.66666667  66.66666667 100.
#    50.          50.          66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 50.          50.          50.         100.          50.
#    50.          50.          66.66666667  66.66666667 100.
#    50.          50.          66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 66.66666667  66.66666667  66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667
#    83.33333333  66.66666667  66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 50.          50.          50.          83.33333333  50.
#    50.          50.          66.66666667  66.66666667  66.66666667
#    50.          50.          66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 50.          50.          50.          66.66666667  50.
#    50.          50.          33.33333333  33.33333333  50.
#    50.          50.          33.33333333  33.33333333  33.33333333
#    33.33333333  33.33333333  33.33333333  33.33333333  33.33333333]
#  [ 50.          50.          50.          83.33333333  50.
#    50.          50.          66.66666667  66.66666667  66.66666667
#    50.          50.          66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 66.66666667  66.66666667  66.66666667  33.33333333  66.66666667
#    66.66666667  66.66666667  33.33333333  33.33333333  50.
#    66.66666667  66.66666667  33.33333333  33.33333333  33.33333333
#    33.33333333  33.33333333  33.33333333  33.33333333  33.33333333]
#  [ 33.33333333  33.33333333  33.33333333  66.66666667  33.33333333
#    33.33333333  33.33333333  66.66666667  66.66666667  66.66666667
#    33.33333333  33.33333333  66.66666667  66.66666667  66.66666667
#    66.66666667  66.66666667  66.66666667  66.66666667  66.66666667]
#  [ 33.33333333  33.33333333  50.          33.33333333  33.33333333
#    33.33333333  33.33333333  33.33333333  33.33333333  66.66666667
#    33.33333333  50.          33.33333333  33.33333333  33.33333333
#    33.33333333  33.33333333  33.33333333  33.33333333  33.33333333]
#  [ 50.          50.          50.          83.33333333  50.
#    50.          50.          33.33333333  33.33333333  66.66666667
#    50.          50.          33.33333333  33.33333333  33.33333333
#    33.33333333  33.33333333  33.33333333  33.33333333  33.33333333]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  seuclidean , Accuracy on these optimal paramters:  100.0
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  100.0
#
# Finished -- BirdChicken  Dataset--##############################################
#
#
# ##############################################-- BME  Dataset -- Started
#
# Full Dataset Shape  (180, 129)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[92.59259259 92.59259259 85.18518519 96.2962963  92.59259259 92.59259259
#   88.88888889 18.51851852 18.51851852 96.2962963  96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [92.59259259 92.59259259 85.18518519 96.2962963  92.59259259 92.59259259
#   88.88888889 18.51851852 18.51851852 96.2962963  96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [88.88888889 88.88888889 85.18518519 88.88888889 88.88888889 88.88888889
#   88.88888889 18.51851852 18.51851852 88.88888889 92.59259259 85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [92.59259259 92.59259259 85.18518519 92.59259259 92.59259259 92.59259259
#   88.88888889 18.51851852 18.51851852 88.88888889 96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 85.18518519 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 85.18518519 96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 85.18518519 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 88.88888889 96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 85.18518519 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 88.88888889 96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 88.88888889 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 88.88888889 96.2962963  85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 88.88888889 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 88.88888889 92.59259259 85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]
#  [85.18518519 85.18518519 85.18518519 88.88888889 85.18518519 85.18518519
#   85.18518519 18.51851852 18.51851852 88.88888889 92.59259259 85.18518519
#   18.51851852 18.51851852 18.51851852 18.51851852 18.51851852 18.51851852
#   18.51851852 18.51851852]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  seuclidean , Accuracy on these optimal paramters:  96.29629629629629
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  96.29629629629629
#
# Finished -- BME  Dataset--##############################################
#
#
# ##############################################-- Car  Dataset -- Started
#
# Full Dataset Shape  (120, 578)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
# Predictions done with k:  10
# K-nearest neighbour finished!!!
# Final validation accuracies after grid search '(x-axis index - k used for prediction, y-xis index- k used for imputing!!!)'
#
# [[72.22222222 72.22222222 66.66666667 61.11111111 72.22222222 72.22222222
#   72.22222222 22.22222222 22.22222222 61.11111111 50.         66.66666667
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [72.22222222 72.22222222 66.66666667 61.11111111 72.22222222 72.22222222
#   72.22222222 22.22222222 22.22222222 61.11111111 50.         66.66666667
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [61.11111111 61.11111111 61.11111111 55.55555556 61.11111111 61.11111111
#   61.11111111 22.22222222 22.22222222 50.         61.11111111 66.66666667
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]
#  [55.55555556 55.55555556 66.66666667 50.         55.55555556 55.55555556
#   55.55555556 16.66666667 16.66666667 50.         72.22222222 66.66666667
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [66.66666667 66.66666667 66.66666667 50.         66.66666667 66.66666667
#   66.66666667 16.66666667 16.66666667 50.         66.66666667 66.66666667
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [61.11111111 61.11111111 55.55555556 44.44444444 61.11111111 61.11111111
#   61.11111111 16.66666667 16.66666667 55.55555556 55.55555556 55.55555556
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [55.55555556 55.55555556 55.55555556 44.44444444 55.55555556 55.55555556
#   55.55555556 16.66666667 16.66666667 55.55555556 50.         55.55555556
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [55.55555556 55.55555556 50.         44.44444444 55.55555556 55.55555556
#   55.55555556 16.66666667 16.66666667 50.         50.         50.
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [55.55555556 55.55555556 50.         44.44444444 55.55555556 55.55555556
#   55.55555556 16.66666667 16.66666667 55.55555556 50.         50.
#   16.66666667 16.66666667 16.66666667 16.66666667 16.66666667 16.66666667
#   16.66666667 16.66666667]
#  [55.55555556 55.55555556 50.         38.88888889 55.55555556 55.55555556
#   55.55555556 22.22222222 22.22222222 50.         38.88888889 50.
#   22.22222222 22.22222222 22.22222222 22.22222222 22.22222222 22.22222222
#   22.22222222 22.22222222]]
#
#  Optimal K for prediction:  1 , Optimal distance measure for prediction:  euclidean , Accuracy on these optimal paramters:  72.22222222222221
#
# Calculating test accuracy by using optimal k value for prediction along with optimal distance measure!!!
#
# Final accuracy on test data:  77.77777777777779
#
# Finished -- Car  Dataset--##############################################
#
#
# ##############################################-- CBF  Dataset -- Started
#
# Full Dataset Shape  (930, 129)
# Check if dataset has null values or missing values!!!  False
#
# K-nearest neighbour started!!!
# Predictions done with k:  1
# Predictions done with k:  2
# Predictions done with k:  3
# Predictions done with k:  4
# Predictions done with k:  5
# Predictions done with k:  6
# Predictions done with k:  7
# Predictions done with k:  8
# Predictions done with k:  9
